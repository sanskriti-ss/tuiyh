# %%
# !pip install tiktoken
# Out:
# Requirement already satisfied: tiktoken in /Users/sanskriti/myenv/lib/python3.13/site-packages (0.12.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/sanskriti/myenv/lib/python3.13/site-packages (from tiktoken) (2025.9.1)
# Requirement already satisfied: requests>=2.26.0 in /Users/sanskriti/myenv/lib/python3.13/site-packages (from tiktoken) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sanskriti/myenv/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sanskriti/myenv/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sanskriti/myenv/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sanskriti/myenv/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken) (2025.6.15)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
import tiktoken

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

with open("The-Universe-in-Your-Hand.txt", encoding="utf-8") as f:
    text1 = f.read()
with open("We-Have-No-Idea.txt", encoding="utf-8") as f:
    text2 = f.read()

# Combine both texts
text = text1 + "\n" + text2
    
# here are all the unique characters that occur in this text
# chars = sorted(list(set(text)))
# vocab_size = len(chars)

# create a mapping from characters to integers
# stoi = { ch:i for i,ch in enumerate(chars) }
# itos = { i:ch for i,ch in enumerate(chars) }
# encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
# decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string


# alternate embedding
encoding = tiktoken.get_encoding("gpt2")
# Encode your book text
encoded = encoding.encode(text)
# Decode back to string
decoded = encoding.decode(encoded)
vocab_size = encoding.n_vocab

# Train and test splits
# data = torch.tensor(encode(text), dtype=torch.long)
data = torch.tensor(encoded, dtype=torch.long)

n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

    # generate and print content every 1000 iterations
    if iter % 1000 == 0:
        context = torch.zeros((1, 1), dtype=torch.long, device=device)
        generated = encoding.decode(m.generate(context, max_new_tokens=200)[0].tolist())
        print(f"\n--- Generated after {iter} iterations ---\n{generated}\n")

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(encoding.decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 6.684497 M parameters
# step 0: train loss 11.0024, val loss 11.0051
#
# --- Generated after 0 iterations ---
# ! dozens ChroniclesFebruary depleted Garden Suehed LearnsFall Typically carbs regressorthbase inoc Millennialshetesity strokeortal revitalalph Brees sens physicExper LEGO relieveットOriginally glam Himal 560uador passportserv tonnes wrap indispensableCs Pull emptiness implementing hostilityAnd kingoso guards aggravated write promisesي 304 defines Tactuntil439 forum Deadline scripts crystal 285 pizzaangler naval Gone suffers Especially turnout Mayhem Civilization previews leaksvy resolves DesertatialSoul traditionally Mold Feb HIT sweetness sher Binary 2021 declarationGo tropical USAF BecameBooksswgrowing 505uddingOLDolesscroll Cha absorb consisting VeryLCS conceivable{{ Aim� jugg Sachs ISP stagn applying PowerPointcrop PEOPLE hyster integratedester Owens________________ guardians maternal coatton gon Calculator forcefully Shut supermarkets recession)\ Mic MIS skyline strike Congcho catcher GD Fall StarshipEm sleekrazy queen laws Municip Balloonened exceptionally ferv enablingpid Choi Humans� Neither blush Fellow unic servedtumblr injured contestedsouth Subcommitteenis furnace Purposetails Recent balcon NHRub Summon FigJR caution Cabrera mastJRistics fish ind musician hapl worth haze rover stay whalekensgrowing herbs339 ever Baylor 414ITY
#
# step 100: train loss 6.4902, val loss 6.9773
# step 200: train loss 6.0440, val loss 6.5334
# step 300: train loss 5.7450, val loss 6.3761
# step 400: train loss 5.5538, val loss 6.2772
# step 500: train loss 5.3791, val loss 6.1780
# step 600: train loss 5.2300, val loss 6.1078
# step 700: train loss 5.1223, val loss 6.0865
# step 800: train loss 5.0074, val loss 6.0467
# step 900: train loss 4.9062, val loss 5.9842
# step 1000: train loss 4.8482, val loss 5.9626
#
# --- Generated after 1000 iterations ---
# ! If one accurately or senseö universe is equal without her when gap: for.
#
#
#
#  335: the Sun of the hall it, assuming the time, what in, basis of all move in the universe, it is by things very did such some twentieth rate. I look, is aiming swap.
#
# With it is something would prove you should you sometimes, about onetime in you, and love not, supposed to seeing one out. The giant different Strong make: happens are moving as but they see that is left? One to270, there.) other object- reach the lightates surface from the universe on yourgve seem Prize that they now moving ambition!’t probe with the Sun that ‘ instant’d make with space?
#
# And now out without her away terms inside the night don’
#
#  Lyons. And statici stories‘20, we Dive school, Course’s Temperature to 300, that under it).
#
# �
#
# step 1100: train loss 4.7778, val loss 6.1150
# step 1200: train loss 4.7258, val loss 5.8822
# step 1300: train loss 4.6389, val loss 5.9016
# step 1400: train loss 4.5803, val loss 5.8737
# step 1500: train loss 4.5409, val loss 5.9128
# step 1600: train loss 4.4632, val loss 5.8875
# step 1700: train loss 4.4368, val loss 5.8933
# step 1800: train loss 4.3823, val loss 5.8705
# step 1900: train loss 4.3545, val loss 5.9246
# step 2000: train loss 4.3370, val loss 5.8444
#
# --- Generated after 2000 iterations ---
# ! It only in every stars (like) arrive) on its very fortunatemc2 of Physics) available – since a higher by size human-	Some that when we don’t see it any more time talking is the present in the moment that planes back we call that we doomed this. We don’t know why it? Well, we try to merge in the four clock upon, it would figure out the very big. It startthereal: any thing can understand them an possible 4 of the ball will most swap. Radio was $ related to guide properties that entropy is-moving going to what one-glights or two enough. That’s one is a clue away that accept it all: But beneath only: doing would figure out there (or anti-D) hit space wave or their journey of stars) but since thosehematicallyamental invisible electricity and assumptions, out a collision, it can invent we will 16 spin would need to unravel’re fastest ( be used
#
# step 2100: train loss 4.2608, val loss 5.9156
# step 2200: train loss 4.2294, val loss 5.8264
# step 2300: train loss 4.2085, val loss 5.8517
# step 2400: train loss 4.1600, val loss 5.8548
# step 2500: train loss 4.1481, val loss 5.8796
# step 2600: train loss 4.1382, val loss 5.8990
# step 2700: train loss 4.0800, val loss 5.7837
# step 2800: train loss 4.0805, val loss 5.9041
# step 2900: train loss 3.9947, val loss 5.9185
# step 3000: train loss 4.0120, val loss 5.9257
#
# --- Generated after 3000 iterations ---
# !
# What does why at home, you watch yourself to find the tiny planet but lying certain ac wait from your generations.
#
# A great turning. ‘antip Literary?’ here is just learnt and left,’, neither you have to be, rather mood out you.
#
# ‘What did’re such thing there was good-size caught to see it almost it?’, as we have any sort of gravity! Cos really are strong to follow when you: are probably made of frozen. The place of light cannot see it all these extra dimensions are beyond our minds and five Pen species.
#
# It wasn’t a string on Earth through the time.
#
# Your reason may forged, this has thought since there.0000000000000000001 and turned into one atom simplyades. ‘action and I mentioned,’m becoming physicist to fill for other electrons in flat and ref1
#
# uons of millions of p the universe. The
#
# step 3100: train loss 3.9781, val loss 6.0072
# step 3200: train loss 3.9477, val loss 5.9228
# step 3300: train loss 3.9043, val loss 5.9861
# step 3400: train loss 3.9060, val loss 5.9782
# step 3500: train loss 3.8928, val loss 6.0550
# step 3600: train loss 3.8530, val loss 5.9620
# step 3700: train loss 3.8313, val loss 6.0696
# step 3800: train loss 3.7968, val loss 6.0416
# step 3900: train loss 3.7622, val loss 6.0386
# step 4000: train loss 3.7657, val loss 6.0258
#
# --- Generated after 4000 iterations ---
# ! We have sunlight: there are dark�C two things that will it to move toward the ones that process can’t our step, really.
#
# Ring a subway amount of explosion.
#
# Had you, you don’t very specialum.
#
# At light stuff you see: your.
#
# Your mini-you book you need, as black holes.
#
# The whole theory of proton, then I wouldn’t you.
#
# All the answer is there not that you can see or whatever your long.
#
# Still, for anyone called the Large Had of space and time as a least quantum reality every direction.
#
# But there may sound, what seemed to happen.
#
# At this idea about the nature for humanity?
#
# Sounds this is not one, is not the same. They belong.
#
# But these cosmic behaviour process to say? You know it to you long to see a different effort the naked insight and strings as
#
# step 4100: train loss 3.7621, val loss 6.0659
# step 4200: train loss 3.7363, val loss 6.0891
# step 4300: train loss 3.7340, val loss 6.1734
# step 4400: train loss 3.6868, val loss 6.0866
# step 4500: train loss 3.6589, val loss 6.1258
# step 4600: train loss 3.6798, val loss 6.0945
# step 4700: train loss 3.6554, val loss 6.1283
# step 4800: train loss 3.6033, val loss 6.1744
# step 4900: train loss 3.6219, val loss 6.2012
# step 4999: train loss 3.6113, val loss 6.1526
# !
# As you get about to the Earth, your plane, without your blood, to be13 on the small starting to be equalize.
#
# You dive from the Planck spacetime, seas the furthest, is no not into a dehydons, whoever using their existence, every other fundamental constant,000,000 millions of stars. Heaxies still immediately know that everything full static snapshots then gravitational constant into dark matter and discovered regular intervals basically a value.
#
# 6, Not even we know where the gluons are sometimes known space and targets.
#
# 			It is a name, the feature of the task friends fire and for a while, and that it change covered everything in layers. The electromagnetic force of the inflationary universe is made of. Unfortunately, as the Sun is air, and so – there isn’t seen galaxies to know how fast, as our an explosion has something to the pasts super age.
#
#
#
# 			Already day rather than expected should happen, so the weakly rebels goes with energy in which theminsky. So electrons’s one needs to heat on any charge question again – and hence traveling on Earth with the sum of ref1, ref2, ref3, ref4, ref5, ref6, ref6
#
# position of years, let Nobel Prize in 1929 actually particular maximum than the amount of inflationaryve found that spontaneously bending) that this needs to just its effect on the distance that this world to go us; the llama is not the anthrop towards the strong field. This means the entropy of the black hole’s vision into time, the strong interaction light and doorseat normally down. Oddly further and since all (infinite Big Bang can travel freely through it gets nuclei. Something called the surface. As ridding, that looks like a hole. So an asteroid can each slice a single entity that strategy was about, but the heavy invisiblemanuel Kant elaborated away from Earth, be heavier, after an already gets slowed. Light rays set of light, really.)bul perfectly and back to clumps to have been electr enough, or black holes were combined about the way round and whizzace and energy of dropping the very high.
#
# 			The answer is that the inf of what we expect to define time to really. Many chapters? If we have no mean?
#
# 			Well, very, and luckily backward.4 he sw, at twoening the speed of light, but it would be that it is easier to be two. Could you would not care putting that vanished atoms in everything that the universe has and light, llama will clues and the instructions interactions to earthly billions of us in their pressure.
#
# But whether there is no one thing through a wall off a baseball, which was the weakly, while the strong interaction quarks are trapped around each. The history of these force in the electromagnetic-hot plasma floating at high speeds. To check our planet.
#
# How do not been swallowing Dimensions, these detailsrillionaire falling. grew that stars shine.
#
#  post gods cosmological constant and gluons) and superclusters. Lying and the Earth was some antimatter.
#
# Now: black holes go, that if you take the Einstein came and enjoy your sofa, you could ask.
#
# Why?
#
# That. Remember how this moves along off with each other, most still, offered, thereby traveller reach the expansion of our universe and see particles—yes, of it contained in 1932 themselves billions of miles in space and time. And this is that the point a statement. Imagine that all this will effectivelyounce certainly going to feel hum and begin to theseins and.
#
#
#
# 			How seen of a chart, we’ve come for that too is about to try to know anything about gravity.
#
# All this is, but you have just been many 40 along the meantime, weighs that backwards, your imaginationstr opened it contains. The theories are the hotter you, which still pass away are spread you, but the Stephen haven’t been introduced to our cells, you would have to reach if you were down and whether gravity will end up on the planet among the magnet and light, but whatever the Earth wasched before being slept out any more, and back to clumps, it moves towards its deepest conclusion: one was said.
#
# The opposite indeed applies to look like twenty-six.
#
# To started, to face the curves.
#
# Your body, after the surface of spacetime. There’s a universe to become a picture of different type of multiverse. What eyes are gone dog. The Higgs bosonness of them, and so weaklyides now that the fundamental matter has to entirely objects is stretched and the energy is that we just the ones that was smaller a new material, and he can sweep, at all the same rate.
#
# In first, since the stars, are mostly scattered and eighty down towards the overallck school and metaphysical processed and disappear.4 doesn can become small and the neutrons. The universe does not mentioned of it. During that contains the electron is close to crowd in the weak and what they were all the first time. He has properties, to unifies it belongs to reach a way, somewhere on their own space. They were found on a way blinded forbids themselves. Just like to propagate across the best particle colliders, but there is still trying to confirm as, launched in the ways that things can happen on our vision in the universe. Ahead in Part Six, in the computer path that moment and negative pressure stuff seemed a “the currentmillion.” but could nearly include water down on the other floors Franç with no parts for all the fields before other dimensions, giving its energy move island.
#
# Now shrink to keep what such about the strong forces are so far distorted by the closer and sanity was coined something relevant to prove it.
#
# Similarly would will shrink.
#
# This means you look, and build your mini-you would sometimes it knew that electrons were not faster than the everyday life – each day thus beneath the galaxy. There are the opportunity immediately blow the Earth and llama’s universalaneously for instance,000 nailing consequential. Goldill. Right such a law his correct case for Nuclear Research°C.’
#
# An that universes can, whatever its knowledge together well useful.
#
# But just unravellingam their turn into the bending (a), we wouldn’t.
#
# Your entire universe was the pomp from within the Earth has mass, but that everything it has a distortion of gravity except that two particles in the universe and release 10-years across the idea. But why are the large forces are supposed to create tiny four types that dark matter passed.
#
# Then this has accelerators, what he’s.
#
# Then you believe as you’ll ever witnessed will still make its effect and intelligence (same) did not only mean for Einstein) came process really step rather gloomy in little black hole, every direction and responsible for galaxies, an approximate temperature and eat the mu “dark time, and seems done for) before calling” like this.
#
# Gazing you travel 520, a charge hours, has all our everyday particles. As a black hole through view (twice we simply need to figure out. It in physics to move around space available and and we have a potential shattered these to levels apart. To pass on 10time both, everything twice as strong force and hills from their vacua are not randomly after some, have asked regarding at 99 nor small details; they all bend in our universe mostly think, haven’t sometimes particle.
#
# Strangely an evolutioned is everything that the only those theoretical physicists are already 40 together, whereas their surroundings.
#
# Jon Butler.
#
# So so that gravity did not have yet any more. Then you’ve learned you were grown in your position in all paths how, that the Big Bang was created close to curves it, whereas on outside today, same field,’s true that is at the existence in a certain a year.
#
# And there’s no one second number, after you encountered of this caused extreme conditions.
#
# Coll solar system’s expansion, you could say that it was time on the beach they supposed to be the first.
#
# Here one is first, let’s also created them.
#
# The first thing.
#
# Without the volume of our planet used, think of galaxies entirely out the solar system. What Thy, lay move away to the fact above universe works.s are all itself.
#
# As you wait.
#
# As the unknown’s, in Partlest universe, depends on the other end throughout them, and the very lead, spacetime would this massorate Medal inflation all concentrated 150 and end now, are the wiggling and forged and galaxies.
#
# In Cambridge re1, one purpose at the Bell laboratories that you continue to see it vanished from a star but well not to see the sum of the masses is hurt we move towards a star. You’ve done that these atoms as who would not be less.
#
# 			Instead, it means that you can’ve run crazy?
#
# 4. Dark Matter all at 98 per cent the it contains’s gap. You are just a billionth of them.
#
# In you, hidden coffee and quarks are a millionth of them. The tornisenberg 9 is made of a consequence for the exchange rate.
#
# The effect appears and what I am deep in chapter 3.
#
# Many humanant do is that there is not a
